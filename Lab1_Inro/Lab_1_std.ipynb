# %%
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np
from skimage.util import random_noise
import numpy as np

from skimage.exposure import histogram
from matplotlib.pyplot import bar

# %%
def show_images(images,titles=None):
    #This function is used to show image(s) with titles by sending an array of images and an array of associated titles.
    # images[0] will be drawn with the title titles[0] if exists
    # You aren't required to understand this function, use it as-is.
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure()
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n)
        if image.ndim == 2: 
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
        n += 1
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_ims)
    plt.show()

# %%
# Ex: imread and imshow 
pyramids = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/pyramids.jpeg")
io.imshow(pyramids)
io.show()

# %%
# Use this function to show a histogram
# The image should be gray-scale and should range from 0 to 1
def showHist(img,histogramImg):
    plt.figure()
    bar(histogramImg[1]*255, histogramImg[0], width=0.8, align='center')

# %%
'''
@TODO:
Requirement #1 
-Read and print image 'coffee'  
-Show and print half of the  image
-----hint :use the attribute shape of numpy to get the image object dimentions
'''
coffee = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/coffee.jpeg")
io.imshow(coffee)
io.show()
print("total shape of img ",coffee.shape)

print("-------half of the img horizontally-------")
io.imshow(coffee[coffee.shape[0]//2:coffee.shape[0]])
io.show()
print("-------half of the img vertically-------")
io.imshow(coffee[:,coffee.shape[1]//2:coffee.shape[1]])
io.show()
# Out:
# total shape of img  (446, 640, 3)
# -------half of the img horizontally-------
# -------half of the img vertically-------

# %%
'''
@TODO:
Requirement #2 
RGB to gray and HSV:
1- Write a function 'gray_image' that takes an image as input , then
    -get the gray scale of the image, then
    -display original image and the gray scale one side by side (subplot).
    -hint: use rgb2gray to get the graylevel of the image
- test your function with the image 'pyramids'

2- Write a function 'HSV_image' that takes an image as input , then
   -show the RGB image and the (3 channels of HSV image each channel in separated form ) one side by side (subplot).
   -hint: -use rgb2hsv (to get the hsv representation of the image).
          -To separately get the Hue, Saturation and Value channels, use hsvImg[:,:,X], 
           where hsvImg is the hsv representation of the image. 
           Hue is the first channel, Saturation is the second and value is the last channel.
- test your function for the images in HSV Folder. And comment on the results. 
'''
def gray_image(img):
    grayImg = rgb2gray(img)
#     fig = plt.figure()
#     p1 = fig.add_subplot(1,2,1)#rows,cols,index of the position
#     plt.imshow(img)#save img
#     p2 = fig.add_subplot(1,2,2)
#     plt.imshow(grayImg,cmap='gray')
    show_images([img,grayImg],["Original","Gray Scale"])
    return grayImg

def HSV_image(img):
    hsvImg = rgb2hsv(img)
    show_images([img,hsvImg[:,:,0],hsvImg[:,:,1],hsvImg[:,:,2]],["Original Img","Hue","Saturation","Value"])
#     fig = plt.figure()
#     p1 = fig.add_subplot(2,2,1)#rows,cols,index of the position
#     plt.imshow(img)#show img
#     p2 = fig.add_subplot(2,2,2)
#     plt.imshow(hsvImg[:,:,0])
#     p3 = fig.add_subplot(2,2,3)
#     plt.imshow(hsvImg[:,:,1],)
#     p4 = fig.add_subplot(2,2,4)
#     plt.imshow(hsvImg[:,:,2])
#     p1.title.set_text("Original Img")
#     p2.title.set_text("Hue")
#     p3.title.set_text("Saturation")
#     p4.title.set_text("Value")
    return hsvImg
    
    
gImg = gray_image(pyramids)
print("Gray Scale Shape : ",gImg.shape)
ex1 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/hsv/ex1.png")
hsvImg1 = HSV_image(ex1)

ex2 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/hsv/ex2.jpg")
hsvImg2 = HSV_image(ex2)

ex3 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/hsv/ex3.jpg")
hsvImg3 = HSV_image(ex3)
# Out:
# Gray Scale Shape :  (960, 640)

# %%
'''
Requirement 2 (Noise):
http://scikit-image.org/docs/dev/api/skimage.util.html#skimage.util.random_noise

1.For an image of your choice (the effect of noise must be obvious): 
    Read the image.
    Convert it to greyscale.
    Apply salt & pepper noise with 
    amount=0.05, 0.5 and 0.9
   
2. From the other images. Recommend one image that won’t be greatly affected by the noise and state why.    
    '''
myImg = io.imread("D:/patora/photo_2021-10-19_22-15-37.jpg")
io.imshow(myImg)
io.show()
gryImg = rgb2gray(myImg)
print("amount = 0.05")
n1 = random_noise(gryImg,mode='s&p',amount=0.05)
io.imshow(n1)
io.show()
print("amount = 0.5")
n2 = random_noise(gryImg,mode='s&p',amount=0.5)
io.imshow(n2)
io.show()
print("amount = 0.9")
n3 = random_noise(gryImg,mode='s&p',amount=0.9)
io.imshow(n3)
io.show()

#________________2__________________
img = io.imread("../Lab1-std/light-gray-color-solid-background-1920x1080.png")
io.imshow(img)
io.show()

gryImg = rgb2gray(img[:,:,:3])
# gryImg = img
n1 = random_noise(gryImg,mode='s&p',amount=0.05)
io.imshow(n1)
io.show()
print("amount = 0.5")
n2 = random_noise(gryImg,mode='s&p',amount=0.5)
io.imshow(n2)
io.show()
print("amount = 0.9")
n3 = random_noise(gryImg,mode='s&p',amount=0.9)
io.imshow(n3)
io.show()
# Out:
# amount = 0.05
# amount = 0.5
# amount = 0.9
# amount = 0.5
# amount = 0.9

# %%
'''
Requirement 3 (Histogram):

1- For the given images ( in histogram folder): 
    Read the image.
    Apply histogram and show it.
Hint
    A) Use histogram (image) to get histogram. Try different values for nbins (256,64,8), What does it mean?
    B) and function(showHist) to draw it.
** 2- Draw a grey-scale image that has uniform histogram 
same number of pixels for all intensity levels) using code only. Let the size of the image be 256x256.
use np.ones to draw image with ones.
'''
ex1 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/histogram/ex1.jpg")
ex2 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/histogram/ex2.png")
ex3 = io.imread("D:/CMP/third_Year/first_Semester/imageProcessing and computerVision/labs/Lab1-std/histogram/ex3.png")
show_images([ex1,ex2,ex3],["ex1","ex2","ex3"])
gex1 = rgb2gray(ex1)
gex2 = rgb2gray(ex2[:,:,:3])#because this pic's extension is .png so to ignore the transparency
gex3 = rgb2gray(ex3)
print("ex1")
hist = histogram(gex1,nbins=256)
showHist(gex1,hist)
hist = histogram(gex1,nbins=64)
showHist(gex1,hist)
hist = histogram(gex1,nbins=8)
showHist(gex1,hist)
# Out:
# ex1

# %%
print("ex2")
hist = histogram(gex2,nbins=256)
showHist(gex2,hist)
hist = histogram(gex2,nbins=64)
showHist(gex2,hist)
hist = histogram(gex2,nbins=8)
showHist(gex2,hist)
# Out:
# ex2

# %%
print("ex3")
hist = histogram(gex3,nbins=256)
showHist(gex3,hist)
hist = histogram(gex3,nbins=64)
showHist(gex3,hist)
hist = histogram(gex3,nbins=8)
showHist(gex3,hist)
# Out:
# ex3

# %%
myImg = np.zeros((256,256))
for i in range(256):
    myImg[i]+=i
show_images([myImg])
myImg = myImg/255
hist = histogram(myImg,nbins=256)
showHist(myImg,hist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\CMP\third_Year\first_Semester\imageProcessing and computerVision\labs\Lab1-std\Lab_1_std.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/CMP/third_Year/first_Semester/imageProcessing%20and%20computerVision/labs/Lab1-std/Lab_1_std.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> myImg = np.zeros((256,256))
#       <a href='vscode-notebook-cell:/d%3A/CMP/third_Year/first_Semester/imageProcessing%20and%20computerVision/labs/Lab1-std/Lab_1_std.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> for i in range(256):
#       <a href='vscode-notebook-cell:/d%3A/CMP/third_Year/first_Semester/imageProcessing%20and%20computerVision/labs/Lab1-std/Lab_1_std.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     myImg[i]+=i
#
# NameError: name 'np' is not defined
